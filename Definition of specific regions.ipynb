# %%
# Basic libraries
import numpy as np
import xarray as xr
import matplotlib.pyplot as plt
from pandas.plotting import register_matplotlib_converters

# Libraries for maps
import cartopy.crs as ccrs
import cartopy.feature as cfeature

# %% [markdown]
# Define subregions in the Mediterranean

# %% [markdown]
# Mediterrenean sea

# %%
fig = plt.figure(figsize=(10,10)) 
ax = fig.add_axes([0.5, 1, 0.3, 0.2], projection=ccrs.PlateCarree())
ax.coastlines()
ax.add_feature(cfeature.BORDERS, zorder=1, edgecolor='k')
ax.add_feature(cfeature.RIVERS, linewidth=0.5)
    
gl = ax.gridlines(draw_labels=True)
gl.right_labels = False
gl.top_labels = False

# Customize mini map
ax.add_feature(cfeature.LAND, zorder=0, edgecolor='k')                  # add land mask
ax.set_extent([-10, 37, 30, 48], crs = ccrs.PlateCarree())               # define the extent of the mini map [lon_min,lon_max,lat_min,lat_max]

# %% [markdown]
# Western Mediterrenean sea

# %%
fig = plt.figure(figsize=(10,10)) 
ax = fig.add_axes([0.5, 1, 0.3, 0.2], projection=ccrs.PlateCarree())
ax.coastlines()
ax.add_feature(cfeature.BORDERS, zorder=1, edgecolor='k')
ax.add_feature(cfeature.RIVERS, linewidth=0.5)
    
gl = ax.gridlines(draw_labels=True)
gl.right_labels = False
gl.top_labels = False

# Customize mini map
ax.add_feature(cfeature.LAND, zorder=0, edgecolor='k')                  # add land mask
ax.set_extent([-10, 11, 30, 48], crs = ccrs.PlateCarree())               # define the extent of the mini map [lon_min,lon_max,lat_min,lat_max]

# %% [markdown]
# Eastern Mediterrenean sea

# %%
fig = plt.figure(figsize=(10,10)) 
ax = fig.add_axes([0.5, 1, 0.3, 0.2], projection=ccrs.PlateCarree())
ax.coastlines()
ax.add_feature(cfeature.BORDERS, zorder=1, edgecolor='k')
ax.add_feature(cfeature.RIVERS, linewidth=0.5)
    
gl = ax.gridlines(draw_labels=True)
gl.right_labels = False
gl.top_labels = False

# Customize mini map
ax.add_feature(cfeature.LAND, zorder=0, edgecolor='k')                  # add land mask
ax.set_extent([11, 37, 30, 48], crs = ccrs.PlateCarree())               # define the extent of the mini map [lon_min,lon_max,lat_min,lat_max]

# %% [markdown]
# Aegean

# %%
fig = plt.figure(figsize=(10,10)) 
ax = fig.add_axes([0.5, 1, 0.3, 0.2], projection=ccrs.PlateCarree())
ax.coastlines()
ax.add_feature(cfeature.BORDERS, zorder=1, edgecolor='k')
ax.add_feature(cfeature.RIVERS, linewidth=0.5)
    
gl = ax.gridlines(draw_labels=True)
gl.right_labels = False
gl.top_labels = False

# Customize mini map
ax.add_feature(cfeature.LAND, zorder=0, edgecolor='k')                  # add land mask
ax.set_extent([22, 28, 35.5, 41], crs = ccrs.PlateCarree())               # define the extent of the mini map [lon_min,lon_max,lat_min,lat_max]

# %% [markdown]
# Ionian

# %%
fig = plt.figure(figsize=(10,10)) 
ax = fig.add_axes([0.5, 1, 0.3, 0.2], projection=ccrs.PlateCarree())
ax.coastlines()
ax.add_feature(cfeature.BORDERS, zorder=1, edgecolor='k')
ax.add_feature(cfeature.RIVERS, linewidth=0.5)
    
gl = ax.gridlines(draw_labels=True)
gl.right_labels = False
gl.top_labels = False

# Customize mini map
ax.add_feature(cfeature.LAND, zorder=0, edgecolor='k')                  # add land mask
ax.set_extent([15, 23.5, 36, 40], crs = ccrs.PlateCarree())               # define the extent of the mini map [lon_min,lon_max,lat_min,lat_max]

# %% [markdown]
# Adriatic

# %%
fig = plt.figure(figsize=(10,10)) 
ax = fig.add_axes([0.5, 1, 0.3, 0.2], projection=ccrs.PlateCarree())
ax.coastlines()
ax.add_feature(cfeature.BORDERS, zorder=1, edgecolor='k')
ax.add_feature(cfeature.RIVERS, linewidth=0.5)
    
gl = ax.gridlines(draw_labels=True)
gl.right_labels = False
gl.top_labels = False

# Customize mini map
ax.add_feature(cfeature.LAND, zorder=0, edgecolor='k')                  # add land mask
ax.set_extent([12, 19.5, 40, 46], crs = ccrs.PlateCarree())               # define the extent of the mini map [lon_min,lon_max,lat_min,lat_max]

# %% [markdown]
# Levantine

# %%
fig = plt.figure(figsize=(10,10)) 
ax = fig.add_axes([0.5, 1, 0.3, 0.2], projection=ccrs.PlateCarree())
ax.coastlines()
ax.add_feature(cfeature.BORDERS, zorder=1, edgecolor='k')
ax.add_feature(cfeature.RIVERS, linewidth=0.5)
    
gl = ax.gridlines(draw_labels=True)
gl.right_labels = False
gl.top_labels = False

# Customize mini map
ax.add_feature(cfeature.LAND, zorder=0, edgecolor='k')                  # add land mask
ax.set_extent([19.5, 36.5, 30.5, 37.5], crs = ccrs.PlateCarree())               # define the extent of the mini map [lon_min,lon_max,lat_min,lat_max]

# %% [markdown]
# Gulf of Sidra

# %%
fig = plt.figure(figsize=(10,10)) 
ax = fig.add_axes([0.5, 1, 0.3, 0.2], projection=ccrs.PlateCarree())
ax.coastlines()
ax.add_feature(cfeature.BORDERS, zorder=1, edgecolor='k')
ax.add_feature(cfeature.RIVERS, linewidth=0.5)
    
gl = ax.gridlines(draw_labels=True)
gl.right_labels = False
gl.top_labels = False

# Customize mini map
ax.add_feature(cfeature.LAND, zorder=0, edgecolor='k')                  # add land mask
ax.set_extent([15, 20, 30, 32.5], crs = ccrs.PlateCarree())               # define the extent of the mini map [lon_min,lon_max,lat_min,lat_max]

# %% [markdown]
# Strait of Sicily & coasts of Lybia and Tynisia

# %%
fig = plt.figure(figsize=(10,10)) 
ax = fig.add_axes([0.5, 1, 0.3, 0.2], projection=ccrs.PlateCarree())
ax.coastlines()
ax.add_feature(cfeature.BORDERS, zorder=1, edgecolor='k')
ax.add_feature(cfeature.RIVERS, linewidth=0.5)
    
gl = ax.gridlines(draw_labels=True)
gl.right_labels = False
gl.top_labels = False

# Customize mini map
ax.add_feature(cfeature.LAND, zorder=0, edgecolor='k')                  # add land mask
ax.set_extent([9.5, 15.5, 32, 38.2], crs = ccrs.PlateCarree())               # define the extent of the mini map [lon_min,lon_max,lat_min,lat_max]

# %% [markdown]
# Tyrrhenian sea

# %%
fig = plt.figure(figsize=(10,10)) 
ax = fig.add_axes([0.5, 1, 0.3, 0.2], projection=ccrs.PlateCarree())
ax.coastlines()
ax.add_feature(cfeature.BORDERS, zorder=1, edgecolor='k')
ax.add_feature(cfeature.RIVERS, linewidth=0.5)
    
gl = ax.gridlines(draw_labels=True)
gl.right_labels = False
gl.top_labels = False

# Customize mini map
ax.add_feature(cfeature.LAND, zorder=0, edgecolor='k')                  # add land mask
ax.set_extent([8.5, 16, 37.5, 43.5], crs = ccrs.PlateCarree())               # define the extent of the mini map [lon_min,lon_max,lat_min,lat_max]

# %% [markdown]
# Ligurian Sea

# %%
fig = plt.figure(figsize=(10,10)) 
ax = fig.add_axes([0.5, 1, 0.3, 0.2], projection=ccrs.PlateCarree())
ax.coastlines()
ax.add_feature(cfeature.BORDERS, zorder=1, edgecolor='k')
ax.add_feature(cfeature.RIVERS, linewidth=0.5)
    
gl = ax.gridlines(draw_labels=True)
gl.right_labels = False
gl.top_labels = False

# Customize mini map
ax.add_feature(cfeature.LAND, zorder=0, edgecolor='k')                  # add land mask
ax.set_extent([6.5, 11, 42.5, 44.5], crs = ccrs.PlateCarree())               # define the extent of the mini map [lon_min,lon_max,lat_min,lat_max]

# %% [markdown]
# Gulf of Lions

# %%
fig = plt.figure(figsize=(10,10)) 
ax = fig.add_axes([0.5, 1, 0.3, 0.2], projection=ccrs.PlateCarree())
ax.coastlines()
ax.add_feature(cfeature.BORDERS, zorder=1, edgecolor='k')
ax.add_feature(cfeature.RIVERS, linewidth=0.5)
    
gl = ax.gridlines(draw_labels=True)
gl.right_labels = False
gl.top_labels = False

# Customize mini map
ax.add_feature(cfeature.LAND, zorder=0, edgecolor='k')                  # add land mask
ax.set_extent([3, 6.5, 42, 44], crs = ccrs.PlateCarree())               # define the extent of the mini map [lon_min,lon_max,lat_min,lat_max]

# %% [markdown]
# Balearic sea

# %%
fig = plt.figure(figsize=(10,10)) 
ax = fig.add_axes([0.5, 1, 0.3, 0.2], projection=ccrs.PlateCarree())
ax.coastlines()
ax.add_feature(cfeature.BORDERS, zorder=1, edgecolor='k')
ax.add_feature(cfeature.RIVERS, linewidth=0.5)
    
gl = ax.gridlines(draw_labels=True)
gl.right_labels = False
gl.top_labels = False

# Customize mini map
ax.add_feature(cfeature.LAND, zorder=0, edgecolor='k')                  # add land mask
ax.set_extent([-1, 5, 38, 41.5], crs = ccrs.PlateCarree())               # define the extent of the mini map [lon_min,lon_max,lat_min,lat_max]

# %% [markdown]
# Alboran sea

# %%
fig = plt.figure(figsize=(10,10)) 
ax = fig.add_axes([0.5, 1, 0.3, 0.2], projection=ccrs.PlateCarree())
ax.coastlines()
ax.add_feature(cfeature.BORDERS, zorder=1, edgecolor='k')
ax.add_feature(cfeature.RIVERS, linewidth=0.5)
    
gl = ax.gridlines(draw_labels=True)
gl.right_labels = False
gl.top_labels = False

# Customize mini map
ax.add_feature(cfeature.LAND, zorder=0, edgecolor='k')                  # add land mask
ax.set_extent([-6, -1, 35, 37], crs = ccrs.PlateCarree())               # define the extent of the mini map [lon_min,lon_max,lat_min,lat_max]

# %% [markdown]
# Algeria and Tunisia coasts

# %%
fig = plt.figure(figsize=(10,10)) 
ax = fig.add_axes([0.5, 1, 0.3, 0.2], projection=ccrs.PlateCarree())
ax.coastlines()
ax.add_feature(cfeature.BORDERS, zorder=1, edgecolor='k')
ax.add_feature(cfeature.RIVERS, linewidth=0.5)
    
gl = ax.gridlines(draw_labels=True)
gl.right_labels = False
gl.top_labels = False

# Customize mini map
ax.add_feature(cfeature.LAND, zorder=0, edgecolor='k')                  # add land mask
ax.set_extent([-1, 9.8, 35, 40], crs = ccrs.PlateCarree())               # define the extent of the mini map [lon_min,lon_max,lat_min,lat_max]
